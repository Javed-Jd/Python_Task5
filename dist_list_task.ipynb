# %% [markdown]
# # Example1 #

# %%
S1 = {  
    'School_id': '01',
    'School_name': 'Greenwood High',
    'Address': '123 Maple Street',
    'City': 'Springfield',
    'State': 'IL',
    'Zip_code': '62704'


}
S2 = {
    'School_id': '02',
    'School_name': 'Lakeside Academy',
    'Address': '456 Oak Avenue',
    'City': 'Riverside',
    'State': 'CA',
    'Zip_code': '92501'
}

print(f'S1 ={S1}')
print(f'S1 type = {type(S1)}')
# Out:
# S1 ={'School_id': '01', 'School_name': 'Greenwood High', 'Address': '123 Maple Street', 'City': 'Springfield', 'State': 'IL', 'Zip_code': '62704'}
# S1 type = <class 'dict'>

# %% [markdown]
# # List of Dict #

# %%
School = [S1, S2]
print(f'school = {School}')
print(f'school type = {type(School)}')

print (f'S2 = {S2}')
print(f'S2 type = {type(S2)}')
# Out:
# school = [{'School_id': '01', 'School_name': 'Greenwood High', 'Address': '123 Maple Street', 'City': 'Springfield', 'State': 'IL', 'Zip_code': '62704'}, {'School_id': '02', 'School_name': 'Lakeside Academy', 'Address': '456 Oak Avenue', 'City': 'Riverside', 'State': 'CA', 'Zip_code': '92501'}]
# school type = <class 'list'>
# S2 = {'School_id': '02', 'School_name': 'Lakeside Academy', 'Address': '456 Oak Avenue', 'City': 'Riverside', 'State': 'CA', 'Zip_code': '92501'}
# S2 type = <class 'dict'>

# %% [markdown]
# # Dict of Dict #

# %%
S1 = {  
    'School_id': '01',
    'School_name': 'Greenwood High',
    'Address': '123 Maple Street',
    'City': 'Springfield',
    'State': 'IL',
    'Zip_code': '62704'


}
S2 = {
    'School_id': '02',
    'School_name': 'Lakeside Academy',
    'Address': '456 Oak Avenue',
    'City': 'Riverside',
    'State': 'CA',
    'Zip_code': '92501'
}

print(f'S1 ={S1}')
print(f'S1 type = {type(S1)}')
print(f'S2 ={S2}')
print(f'S2 type = {type(S2)}')
# Out:
# S1 ={'School_id': '01', 'School_name': 'Greenwood High', 'Address': '123 Maple Street', 'City': 'Springfield', 'State': 'IL', 'Zip_code': '62704'}
# S1 type = <class 'dict'>
# S2 ={'School_id': '02', 'School_name': 'Lakeside Academy', 'Address': '456 Oak Avenue', 'City': 'Riverside', 'State': 'CA', 'Zip_code': '92501'}
# S2 type = <class 'dict'>

# %% [markdown]
# # Dict fo Dict of List #

# %%
S1 = {  
    'School_id': '01',
    'School_name': 'Greenwood High',
    'Address': '123 Maple Street',
    'City': 'Springfield',
    'State': 'IL',
    'Zip_code': '62704'


}
S2 = {
    'School_id': '02',
    'School_name': 'Lakeside Academy',
    'Address': '456 Oak Avenue',
    'City': 'Riverside',
    'State': 'CA',
    'Zip_code': '92501'
}

print(f'S1 ={S1}')
print(f'S1 type = {type(S1)}')
print(f'S2 ={S2}')
print(f'S2 type = {type(S2)}')
print('-'*20)
print(f'school = {School}')
print(f'school type = {type(School)}')
# Out:
# S1 ={'School_id': '01', 'School_name': 'Greenwood High', 'Address': '123 Maple Street', 'City': 'Springfield', 'State': 'IL', 'Zip_code': '62704'}
# S1 type = <class 'dict'>
# S2 ={'School_id': '02', 'School_name': 'Lakeside Academy', 'Address': '456 Oak Avenue', 'City': 'Riverside', 'State': 'CA', 'Zip_code': '92501'}
# S2 type = <class 'dict'>
# --------------------
# school = [{'School_id': '01', 'School_name': 'Greenwood High', 'Address': '123 Maple Street', 'City': 'Springfield', 'State': 'IL', 'Zip_code': '62704'}, {'School_id': '02', 'School_name': 'Lakeside Academy', 'Address': '456 Oak Avenue', 'City': 'Riverside', 'State': 'CA', 'Zip_code': '92501'}]
# school type = <class 'list'>
